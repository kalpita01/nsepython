# %%
print("hi")
# Out:
# hi

# %%
from pynse import *
nse = Nse()
nse.option_chain('INFY', expiry=dt.date(2021, 5, 27))
# Out:
#      strikePrice  expiryDate  CE.strikePrice CE.expiryDate CE.underlying  \
# 0            800  2021-05-27           800.0   27-May-2021          INFY
# 3            820  2021-05-27           820.0   27-May-2021          INFY
# 4            840  2021-05-27           840.0   27-May-2021          INFY
# 7            860  2021-05-27           860.0   27-May-2021          INFY
# 8            880  2021-05-27           880.0   27-May-2021          INFY
# 10           900  2021-05-27           900.0   27-May-2021          INFY
# 13           920  2021-05-27           920.0   27-May-2021          INFY
# 15           940  2021-05-27           940.0   27-May-2021          INFY
# 17           960  2021-05-27           960.0   27-May-2021          INFY
# 19           980  2021-05-27           980.0   27-May-2021          INFY
# 21          1000  2021-05-27          1000.0   27-May-2021          INFY
# 23          1020  2021-05-27          1020.0   27-May-2021          INFY
# ...
